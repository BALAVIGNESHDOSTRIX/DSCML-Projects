# %%
from google.colab import files
from IPython.display import Image
uploded = files.upload()
# Out:
#      <input type="file" id="files-23cac3ce-2534-4be4-bf21-7d84499440a4" name="files[]" multiple disabled />
#      <output id="result-23cac3ce-2534-4be4-bf21-7d84499440a4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving mlvrlr.png to mlvrlr.png

# %%
Image('mlvrlr.png')

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-90c41282-0267-45fb-8e97-414558eea525" name="files[]" multiple disabled />
#      <output id="result-90c41282-0267-45fb-8e97-414558eea525">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving multi_vr_house_price.csv to multi_vr_house_price.csv

# %%
from sklearn import linear_model
import matplotlib.pyplot as plt
import pandas as pd
import math 

df = pd.read_csv('multi_vr_house_price.csv')
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
#Preprocessing the Datasets
median_bedrooms = df.bedrooms.median()
df.bedrooms = df.bedrooms.fillna(median_bedrooms)
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       4.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
model = linear_model.LinearRegression()
model.fit(df[['area', 'bedrooms', 'age']], df.price)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#Predict Following
''' 
    A: 3000 sqr ft area, 3 bedrooms, 40 year old
    B: 2500 sqr ft area, 4 bedrooms, 5 year old
'''

A = model.predict([[3000,3,40]])
A
# Out:
# array([498408.25158031])

# %%
B = model.predict([[2500,4,5]])
B
# Out:
# array([578876.03748933])
